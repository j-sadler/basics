# %%
import pandas as pd
import numpy as np

# %%
df22 = pd.read_excel('FY22.xlsx', sheet_name='FY22')
new_header = df22.iloc[0].str.strip()
df22.columns = new_header
df22 = df22[1:]
df22.reset_index(inplace=True)

df22['ind'] = df22['ID #'].astype(str) + '-' + df22['Line Item # [BF Line]'].astype(str)

Status = 'Financed'
Funding_Type = 'BA'
Portfolio = 'Enterprise'
df22.drop('index', axis = 1, inplace = True)

df22 = df22[(df22['Status'] == Status) & (df22['Funding Type'] == Funding_Type) & 
        (df22['Portfolio'] == Portfolio) ]
df22.reset_index(inplace=True)
fy22 = pd.DataFrame()
fy22[['Index', 'Portfolio', 'Congressional Project', 'Sub-Project', 'Sub-Account', 
      'Funding']] = df22[['ind', 'Portfolio', 'Congressional Project', 'Sub-Project', 
                        'Sub-Account', '$ BY OMB Passback Amount' ]]

fy22pt = fy22.pivot_table(values= 'Funding',aggfunc=np.sum, index= ('Congressional Project', 
                                                           'Sub-Project'), 
                 columns= 'Sub-Account', fill_value=0)

# %%
fy22['FY'] = 'FY22'

# %%
fy22.head()
# Out:
#      Index   Portfolio            Congressional Project  \
# 0   1615-1  Enterprise                   Cyber Security
# 1  1616-28  Enterprise  Data Integration and Management
# 2   1616-2  Enterprise  Data Integration and Management
# 3  1616-29  Enterprise  Data Integration and Management
# 4  1616-78  Enterprise  Data Integration and Management
#
#                                          Sub-Project Sub-Account Funding    FY
# 0  Identity and Access Management - Enterprise (IAM)         DEV    11.2  FY22
# 1                    ACOE Advanced Tools and Support          OM   8.175  FY22
# 2  Collaborative Terminology Tooling Data Management          OM    2.32  FY22
# 3                         Data Access Services (DAS)          OM      13  FY22
# 4               DevSecOps Advanced Tools and Support          OM       9  FY22

# %%
df21 = pd.read_excel('FY21.xlsx',sheet_name='FY21')

# 'Portfolio [SPI]'
Portfolio = 'Enterprise'
# DT['Funding Status [SPI]']
FundingStatus = ['Approved','Approved (Non-Target)','Prior Year']
# DT['Funding Type [SPI]']
FundingType = 'BA'

dt21 = df21[(df21['Portfolio [SPI]'] == Portfolio) & (df21['Funding Status [SPI]'].isin(FundingStatus))
            & (df21['Funding Type [SPI]'] == FundingType)]
dt21.reset_index(inplace=True)
fy21 = pd.DataFrame()

fy21[['Index', 'Portfolio' , 'Congressional Project', 'Sub-Project', 'Sub-Account', 
      'Funding']] = dt21[['SPI + Strip # [SPI Strip]', 'Portfolio [SPI]' , 'Congressional Project [SPI]'
     , 'Sub-Project [SPI]', 'Sub-Account [SPI Strip]', '$ Obligated Amount [Req Strip]']]

# %%
fy21['FY'] = 'FY21'
fy21['Funding'] = fy21['Funding']/1000000

# %%
fy21.head()
# Out:
#            Index   Portfolio Congressional Project  \
# 0  2021-BEAS-1-1  Enterprise  IT Support Contracts
# 1  2021-BEAS-1-2  Enterprise  IT Support Contracts
# 2  2021-BEAS-1-3  Enterprise  IT Support Contracts
# 3  2021-BEAS-1-4  Enterprise  IT Support Contracts
# 4  2021-BEAS-4-1  Enterprise  IT Support Contracts
#
#                   Sub-Project Sub-Account   Funding    FY
# 0  Budget Tracking Tool (BTT)          OM  0.000000  FY21
# 1  Budget Tracking Tool (BTT)       ADMIN  2.654938  FY21
# 2  Budget Tracking Tool (BTT)       ADMIN  0.584188  FY21
# 3  Budget Tracking Tool (BTT)       ADMIN  0.424728  FY21
# 4  Program Management Support          OM  0.354921  FY21

# %%
fy21_22 = fy21.append(fy22)

# %%
fy21_22.head(10000)
# Out:
#              Index   Portfolio            Congressional Project  \
# 0    2021-BEAS-1-1  Enterprise             IT Support Contracts
# 1    2021-BEAS-1-2  Enterprise             IT Support Contracts
# 2    2021-BEAS-1-3  Enterprise             IT Support Contracts
# 3    2021-BEAS-1-4  Enterprise             IT Support Contracts
# 4    2021-BEAS-4-1  Enterprise             IT Support Contracts
# ..             ...         ...                              ...
# 112         1582-1  Enterprise             Hardware Maintenance
# 113         1577-1  Enterprise             Software Maintenance
# 114         1579-2  Enterprise               Telecommunications
# 115         1579-1  Enterprise               Telecommunications
# 116        1616-83  Enterprise  Data Integration and Management
#
#                                  Sub-Project Sub-Account   Funding    FY
# 0                 Budget Tracking Tool (BTT)          OM       0.0  FY21
# 1                 Budget Tracking Tool (BTT)       ADMIN  2.654938  FY21
# 2                 Budget Tracking Tool (BTT)       ADMIN  0.584188  FY21
# 3                 Budget Tracking Tool (BTT)       ADMIN  0.424728  FY21
# 4                 Program Management Support          OM  0.354921  FY21
# ..                                       ...         ...       ...   ...
# 112            Enterprise Facility Allowance          OM     0.482  FY22
# 113  Enterprise Software License Maintenance          OM   243.983  FY22
# 114                           EIS Transition          OM    18.458  FY22
# 115            Enterprise Telecommunications          OM   274.047  FY22
# 116                           API Management         DEV         8  FY22
#
# [5557 rows x 7 columns]

# %%
fy21_22_pt = fy21_22.pivot_table(values= 'Funding',aggfunc=np.sum, index= ('Congressional Project', 'Sub-Project'), columns= ('FY', 'Sub-Account'), fill_value=0)

# %%
fy21_22_pt.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
fy21_22_pt = fy21_22.pivot_table(values= 'Funding', margins=True,  aggfunc=np.sum, index= ('Congressional Project', 'Sub-Project'), columns= ('FY', 'Sub-Account'), fill_value=0)

# %%
fy21_22_pt
# Out:
# FY                                                                        FY21  \
# Sub-Account                                                              ADMIN
# Congressional Project Sub-Project
# Activations           Activations                                     0.000000
#                       VHA Construction                                0.000000
#                       VHA Growth                                      0.000000
# Cyber Security        Continuous Readiness in Information Security    0.000000
#                       Cyber Security Program Services                 0.000000
# ...                                                                        ...
# TAC Fees              TAC Fees (Acquisition Fees)                    68.155000
# Telecommunications    EIS Transition                                  0.000000
#                       Enterprise Telecommunications                   0.000000
# Unallocated           Unallocated                                     0.000000
# All                                                                 151.015543
#
# FY                                                                            \
# Sub-Account                                                              DEV
# Congressional Project Sub-Project
# Activations           Activations                                    0.00000
#                       VHA Construction                               0.00000
#                       VHA Growth                                     0.00000
# Cyber Security        Continuous Readiness in Information Security   0.00000
#                       Cyber Security Program Services                0.00000
# ...                                                                      ...
# TAC Fees              TAC Fees (Acquisition Fees)                    0.00000
# Telecommunications    EIS Transition                                 0.00000
#                       Enterprise Telecommunications                  0.00000
# Unallocated           Unallocated                                    0.00000
# All                                                                 58.38228
#
# FY                                                                               \
# Sub-Account                                                                  OM
# Congressional Project Sub-Project
# Activations           Activations                                      0.000000
#                       VHA Construction                                79.783384
#                       VHA Growth                                     115.671751
# Cyber Security        Continuous Readiness in Information Security    68.920579
#                       Cyber Security Program Services                  2.093678
# ...                                                                         ...
# TAC Fees              TAC Fees (Acquisition Fees)                     14.631154
# Telecommunications    EIS Transition                                   0.000000
#                       Enterprise Telecommunications                  329.834937
# Unallocated           Unallocated                                      0.000000
# All                                                                 2913.325652
#
# FY                                                                  FY22  \
# Sub-Account                                                          DEV
# Congressional Project Sub-Project
# Activations           Activations                                    0.0
#                       VHA Construction                               0.0
#                       VHA Growth                                     0.0
# Cyber Security        Continuous Readiness in Information Security   0.0
#                       Cyber Security Program Services                0.0
# ...                                                                  ...
# TAC Fees              TAC Fees (Acquisition Fees)                    0.0
# Telecommunications    EIS Transition                                 0.0
#                       Enterprise Telecommunications                  0.0
# Unallocated           Unallocated                                    0.0
# All                                                                 19.2
#
# FY                                                                            \
# Sub-Account                                                               OM
# Congressional Project Sub-Project
# Activations           Activations                                    112.072
#                       VHA Construction                                 0.000
#                       VHA Growth                                       0.000
# Cyber Security        Continuous Readiness in Information Security    51.129
#                       Cyber Security Program Services                  0.000
# ...                                                                      ...
# TAC Fees              TAC Fees (Acquisition Fees)                      0.000
# Telecommunications    EIS Transition                                  18.458
#                       Enterprise Telecommunications                  274.047
# Unallocated           Unallocated                                      0.000
# All                                                                 1772.952
#
# FY                                                                          All
# Sub-Account
# Congressional Project Sub-Project
# Activations           Activations                                    112.072000
#                       VHA Construction                                79.783384
#                       VHA Growth                                     115.671751
# Cyber Security        Continuous Readiness in Information Security   120.049579
#                       Cyber Security Program Services                  2.093678
# ...                                                                         ...
# TAC Fees              TAC Fees (Acquisition Fees)                     82.786154
# Telecommunications    EIS Transition                                  18.458000
#                       Enterprise Telecommunications                  603.881937
# Unallocated           Unallocated                                      0.000000
# All                                                                 4914.875475
#
# [147 rows x 6 columns]

# %%
g = fy21_22_pt.groupby('Congressional Project')['All'].sum().reset_index(name='sum')

# %%
g
# Out:
#                      Congressional Project          sum
# 0                              Activations   307.527135
# 1                                      All  4914.875475
# 2                           Cyber Security   643.299698
# 3          Data Integration and Management   895.019026
# 4                      End User Operations    52.000000
# 5                Enterprise Command Center    12.624000
# 6                Enterprise Infrastructure    10.903462
# 7                  Enterprise Service Desk   131.948025
# 8                     Hardware Maintenance   237.230106
# 9                    IT Service Management   110.759915
# 10                    IT Support Contracts   735.944472
# 11  Infrastructure Readiness Program (IRP)   292.356442
# 12               Network Operations Center    39.866000
# 13            Privacy & Records Management    80.414275
# 14                            Repositories     5.317343
# 15                    Software Maintenance   654.539486
# 16                                TAC Fees    82.786154
# 17                      Telecommunications   622.339937
# 18                             Unallocated     0.000000

# %%
# g = df.groupby(['cnpj','num_doc'])['bc_icms'].sum()

g2 = fy21_22.groupby(['Congressional Project' , 'Sub-Project'])['Funding'].sum().reset_index(name='sum')

# %%
g2
# Out:
#     Congressional Project                                   Sub-Project  \
# 0             Activations                                   Activations
# 1             Activations                              VHA Construction
# 2             Activations                                    VHA Growth
# 3          Cyber Security  Continuous Readiness in Information Security
# 4          Cyber Security               Cyber Security Program Services
# ..                    ...                                           ...
# 141  Software Maintenance              VHA Software License Maintenance
# 142              TAC Fees                   TAC Fees (Acquisition Fees)
# 143    Telecommunications                                EIS Transition
# 144    Telecommunications                 Enterprise Telecommunications
# 145           Unallocated                                   Unallocated
#
#             sum
# 0       112.072
# 1     79.783384
# 2    115.671751
# 3    120.049579
# 4      2.093678
# ..          ...
# 141    5.814984
# 142   82.786154
# 143      18.458
# 144  603.881937
# 145         0.0
#
# [146 rows x 3 columns]

# %%
g3 = fy21_22.groupby(['Congressional Project' , 'Sub-Project'])['Funding'].sum()

# %%
g3
# Out:
# Congressional Project  Sub-Project
# Activations            Activations                                        112.072
#                        VHA Construction                                 79.783384
#                        VHA Growth                                      115.671751
# Cyber Security         Continuous Readiness in Information Security    120.049579
#                        Cyber Security Program Services                   2.093678
#                                                                           ...
# Software Maintenance   VHA Software License Maintenance                  5.814984
# TAC Fees               TAC Fees (Acquisition Fees)                      82.786154
# Telecommunications     EIS Transition                                      18.458
#                        Enterprise Telecommunications                   603.881937
# Unallocated            Unallocated                                            0.0
# Name: Funding, Length: 146, dtype: object
